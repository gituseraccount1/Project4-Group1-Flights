# %% [markdown]
# ## 2023

# %%
import pandas as pd
import requests
from io import StringIO
url = "https://group1-project4-flightdata2023.s3.us-east-2.amazonaws.com/2023.csv"

response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Read the CSV content into a Pandas DataFrame
    pandas_df = pd.read_csv(StringIO(response.text))
    # Now 'pandas_df' is a Pandas DataFrame
    print(pandas_df.head())
else:
    print(f"Failed to fetch the CSV file. Status Code: {response.status_code}")
# Out:
#       FL_DATE AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY  \
# 0  2023-06-04           9E     20363       4628    DSM       Des Moines, IA
# 1  2023-06-01           9E     20363       4628    ROC        Rochester, NY
# 2  2023-06-02           9E     20363       4628    ROC        Rochester, NY
# 3  2023-06-01           9E     20363       4629    ITH  Ithaca/Cortland, NY
# 4  2023-06-02           9E     20363       4629    ITH  Ithaca/Cortland, NY
#
#   DEST     DEST_CITY  CRS_DEP_TIME  DEP_TIME  ...  AIR_TIME  DISTANCE  \
# 0  LGA  New York, NY          1033    1053.0  ...     134.0    1031.0
# 1  LGA  New York, NY          1001     956.0  ...      49.0     254.0
# 2  LGA  New York, NY          1001     956.0  ...      46.0     254.0
# 3  JFK  New York, NY          1452    1447.0  ...      46.0     189.0
# 4  JFK  New York, NY          1452    1448.0  ...      46.0     189.0
#
#    DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  DELAY_DUE_NAS  DELAY_DUE_SECURITY  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Group by airport and count cancelled flights
cancelled_by_airport = pandas_df.groupby('ORIGIN')['CANCELLED'].sum().reset_index()

# Sort the airports by the number of cancelled flights in descending order
top_airports = cancelled_by_airport.sort_values(by='CANCELLED', ascending=False).head(20)

# Plot the top 20 airports
plt.figure(figsize=(10, 6))
plt.bar(top_airports['ORIGIN'], top_airports['CANCELLED'], color='#25316D')
plt.title('Top 20 Airports by Cancelled Flights 2023')
plt.xlabel('Airport Code')
plt.ylabel('Number of Cancelled Flights')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate the total number of flights and the number of cancelled flights
total_flights = len(pandas_df)
cancelled_flights = pandas_df['CANCELLED'].sum()

# Calculate the percentage of cancelled flights
cancelled_percentage = (cancelled_flights / total_flights) * 100

# Create a DataFrame for visualization
data = {'Category': ['Cancelled', 'Not Cancelled'], 'Count': [cancelled_flights, total_flights - cancelled_flights]}
df_visualization = pd.DataFrame(data)

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(df_visualization['Count'], labels=df_visualization['Category'], autopct='%1.1f%%', startangle=90, colors=['red', '#25316D'])
plt.title('Flight Cancellation Rate 2023')
plt.show()

# Alternatively, plot a bar chart
plt.figure(figsize=(8, 6))
plt.bar(df_visualization['Category'], df_visualization['Count'], color=['red', '#25316D'])
plt.xlabel('Flight Status')
plt.ylabel('Number of Flights')
plt.title('Flight Cancellation Rate 2023')
plt.show()

# %%
# Aggregate counts for each cancellation reason
cancellation_reasons = pandas_df[['DELAY_DUE_CARRIER', 'DELAY_DUE_WEATHER', 'DELAY_DUE_NAS', 'DELAY_DUE_SECURITY', 'DELAY_DUE_LATE_AIRCRAFT']]
reason_counts = cancellation_reasons.sum()

# Plot a bar chart
plt.figure(figsize=(10, 6))
reason_counts.plot(kind='bar', color='#25316D')
plt.xlabel('Cancellation Reasons')
plt.ylabel('Number of Cancellations')
plt.title('Reasons for Flight Cancellations 2023')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## 2022

# %%
import pandas as pd
import requests
from io import StringIO
url = "https://group1-project4-flightdata2023.s3.us-east-2.amazonaws.com/2022.csv"

response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Read the CSV content into a Pandas DataFrame
    pandas2_df = pd.read_csv(StringIO(response.text))
    # Now 'pandas_df' is a Pandas DataFrame
    print(pandas2_df.head())
else:
    print(f"Failed to fetch the CSV file. Status Code: {response.status_code}")
# Out:
#       FL_DATE AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN     ORIGIN_CITY DEST  \
# 0  2022-05-03           OH     20397       5433    DCA  Washington, DC  ALB
# 1  2022-05-04           OH     20397       5433    DCA  Washington, DC  ALB
# 2  2022-05-01           OH     20397       5434    CLT   Charlotte, NC  TLH
# 3  2022-05-02           OH     20397       5434    CLT   Charlotte, NC  TLH
# 4  2022-05-03           OH     20397       5434    CLT   Charlotte, NC  TLH
#
#          DEST_CITY  CRS_DEP_TIME  DEP_TIME  ...  AIR_TIME  DISTANCE  \
# 0       Albany, NY          1010    1018.0  ...      61.0     318.0
# 1       Albany, NY          1010    1002.0  ...      61.0     318.0
# 2  Tallahassee, FL          2046    2039.0  ...      57.0     386.0
# 3  Tallahassee, FL          2046    2036.0  ...      60.0     386.0
# 4  Tallahassee, FL          2046    2035.0  ...      63.0     386.0
#
#    DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  DELAY_DUE_NAS  DELAY_DUE_SECURITY  \
# ...

# %%
# Group by airport and count cancelled flights
cancelled_by_airport = pandas2_df.groupby('ORIGIN')['CANCELLED'].sum().reset_index()

# Sort the airports by the number of cancelled flights in descending order
top_airports = cancelled_by_airport.sort_values(by='CANCELLED', ascending=False).head(20)

# Plot the top 20 airports
plt.figure(figsize=(10, 6))
plt.bar(top_airports['ORIGIN'], top_airports['CANCELLED'], color='#97D2EC')
plt.title('Top 20 Airports by Cancelled Flights 2022')
plt.xlabel('Airport Code')
plt.ylabel('Number of Cancelled Flights')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate the total number of flights and the number of cancelled flights
total_flights = len(pandas2_df)
cancelled_flights = pandas2_df['CANCELLED'].sum()

# Calculate the percentage of cancelled flights
cancelled_percentage = (cancelled_flights / total_flights) * 100

# Create a DataFrame for visualization
data = {'Category': ['Cancelled', 'Not Cancelled'], 'Count': [cancelled_flights, total_flights - cancelled_flights]}
df_visualization = pd.DataFrame(data)

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(df_visualization['Count'], labels=df_visualization['Category'], autopct='%1.1f%%', startangle=90, colors=['red', '#97D2EC'])
plt.title('Flight Cancellation Rate 2022')
plt.show()

# Alternatively, plot a bar chart
plt.figure(figsize=(8, 6))
plt.bar(df_visualization['Category'], df_visualization['Count'], color=['red', '#97D2EC'])
plt.xlabel('Flight Status')
plt.ylabel('Number of Flights')
plt.title('Flight Cancellation Rate 2022')
plt.show()

# %%
# Aggregate counts for each cancellation reason
cancellation_reasons = pandas2_df[['DELAY_DUE_CARRIER', 'DELAY_DUE_WEATHER', 'DELAY_DUE_NAS', 'DELAY_DUE_SECURITY', 'DELAY_DUE_LATE_AIRCRAFT']]
reason_counts = cancellation_reasons.sum()

# Plot a bar chart
plt.figure(figsize=(10, 6))
reason_counts.plot(kind='bar', color='#97D2EC')
plt.xlabel('Cancellation Reasons')
plt.ylabel('Number of Cancellations')
plt.title('Reasons for Flight Cancellations 2022')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## COMBINED 2022 and 2023

# %%
combined_df = pd.concat([pandas_df, pandas2_df], ignore_index=True)
combined_df.head()
# Out:
#       FL_DATE AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY  \
# 0  2023-06-04           9E     20363       4628    DSM       Des Moines, IA
# 1  2023-06-01           9E     20363       4628    ROC        Rochester, NY
# 2  2023-06-02           9E     20363       4628    ROC        Rochester, NY
# 3  2023-06-01           9E     20363       4629    ITH  Ithaca/Cortland, NY
# 4  2023-06-02           9E     20363       4629    ITH  Ithaca/Cortland, NY
#
#   DEST     DEST_CITY  CRS_DEP_TIME  DEP_TIME  ...  AIR_TIME  DISTANCE  \
# 0  LGA  New York, NY          1033    1053.0  ...     134.0    1031.0
# 1  LGA  New York, NY          1001     956.0  ...      49.0     254.0
# 2  LGA  New York, NY          1001     956.0  ...      46.0     254.0
# 3  JFK  New York, NY          1452    1447.0  ...      46.0     189.0
# 4  JFK  New York, NY          1452    1448.0  ...      46.0     189.0
#
#    DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  DELAY_DUE_NAS  DELAY_DUE_SECURITY  \
# ...

# %%
combined_df.head()
# Out:
#       FL_DATE AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY  \
# 0  2023-06-04           9E     20363       4628    DSM       Des Moines, IA
# 1  2023-06-01           9E     20363       4628    ROC        Rochester, NY
# 2  2023-06-02           9E     20363       4628    ROC        Rochester, NY
# 3  2023-06-01           9E     20363       4629    ITH  Ithaca/Cortland, NY
# 4  2023-06-02           9E     20363       4629    ITH  Ithaca/Cortland, NY
#
#   DEST     DEST_CITY  CRS_DEP_TIME  DEP_TIME  ...  AIR_TIME  DISTANCE  \
# 0  LGA  New York, NY          1033    1053.0  ...     134.0    1031.0
# 1  LGA  New York, NY          1001     956.0  ...      49.0     254.0
# 2  LGA  New York, NY          1001     956.0  ...      46.0     254.0
# 3  JFK  New York, NY          1452    1447.0  ...      46.0     189.0
# 4  JFK  New York, NY          1452    1448.0  ...      46.0     189.0
#
#    DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  DELAY_DUE_NAS  DELAY_DUE_SECURITY  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Group by airport and count cancelled flights
cancelled_by_airport = combined_df.groupby('ORIGIN')['CANCELLED'].sum().reset_index()

# Sort the airports by the number of cancelled flights in descending order
top_airports = cancelled_by_airport.sort_values(by='CANCELLED', ascending=False).head(20)

# Plot the top 20 airports
plt.figure(figsize=(10, 6))
plt.bar(top_airports['ORIGIN'], top_airports['CANCELLED'], color='#FFB480')
plt.title('Top 20 Airports by Cancelled Flights 2022 and 2023')
plt.xlabel('Airport Code')
plt.ylabel('Number of Cancelled Flights')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate the total number of flights and the number of cancelled flights
total_flights = len(combined_df)
cancelled_flights = combined_df['CANCELLED'].sum()

# Calculate the percentage of cancelled flights
cancelled_percentage = (cancelled_flights / total_flights) * 100

# Create a DataFrame for visualization
data = {'Category': ['Cancelled', 'Not Cancelled'], 'Count': [cancelled_flights, total_flights - cancelled_flights]}
df_visualization = pd.DataFrame(data)

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(df_visualization['Count'], labels=df_visualization['Category'], autopct='%1.1f%%', startangle=90, colors=['red', '#FFB480'])
plt.title('Flight Cancellation Rate 2022 and 2023')
plt.show()

# Alternatively, plot a bar chart
plt.figure(figsize=(8, 6))
plt.bar(df_visualization['Category'], df_visualization['Count'], color=['red', '#FFB480'])
plt.xlabel('Flight Status')
plt.ylabel('Number of Flights')
plt.title('Flight Cancellation Rate 2022 and 2023')
plt.show()

# %%
# Aggregate counts for each cancellation reason
cancellation_reasons = pandas2_df[['DELAY_DUE_CARRIER', 'DELAY_DUE_WEATHER', 'DELAY_DUE_NAS', 'DELAY_DUE_SECURITY', 'DELAY_DUE_LATE_AIRCRAFT']]
reason_counts = cancellation_reasons.sum()

# Plot a bar chart
plt.figure(figsize=(10, 6))
reason_counts.plot(kind='bar', color='#FFB480')
plt.xlabel('Cancellation Reasons')
plt.ylabel('Number of Cancellations')
plt.title('Reasons for Flight Cancellations 2022 and 2023')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# Convert FL_DATE to datetime format
combined_df['FL_DATE'] = pd.to_datetime(combined_df['FL_DATE'])

# Group data by month and count cancellations
monthly_cancellations = combined_df.groupby(combined_df['FL_DATE'].dt.month)['CANCELLED'].sum()

# Plotting the trend
plt.figure(figsize=(10, 6))
plt.plot(monthly_cancellations.index, monthly_cancellations.values, marker='o', linestyle='-', color='#FFB480')
plt.title('Monthly Flight Cancellations Trend 2022 2023')
plt.xlabel('Month')
plt.ylabel('Number of Cancellations')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
num_rows = combined_df.shape[0]
print(f"The DataFrame has {num_rows} rows.")
# Out:
# The DataFrame has 11274547 rows.
